# %%
SOURCE_DATASETS = ["gaugan", "biggan", "cyclegan", "imle", "faceforensics", "crn", "wild"] 
NETWORK = "ResNet"
CHECKPOINT_DIR_SOURCE = "../KD-AIGC-Detection/checkpoints/KD/cddb_easy"
CHECKPOINT_DIR_TARGET = "../KD-AIGC-Detection/checkpoints/KD/cddb_easy"
DATASET_DIR = "../KD-AIGC-Detection/datasets/custom"
COMET_NAME = "e50_wild"


source_string = "_".join(SOURCE_DATASETS)
input_model = f"{CHECKPOINT_DIR_SOURCE}/{source_string}"

source_datasets_string = ",".join([f"{DATASET_DIR}/{ds}" for ds in SOURCE_DATASETS])

for trans in ("contrast", "brightness", "jpeg"):
    COMET_NAME = f"{COMET_NAME}_{trans}"
    # !python ./src/evaluate.py  --network $NETWORK \
        --input_model $input_model \
        --source_datasets $source_datasets_string \
        --use_comet \
        --val_transforms $trans \
        --comet_name $COMET_NAME
# Out:
# COMET INFO: Experiment is live on comet.com https://www.comet.com/francescotss/paper-review/4b43731ec7614f93a75dc0465c9b198f
#
#
#
#
# ------ Creating Loaders ------
# GPU num is 0
#
# ===> Making Loader Testing
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/gaugan/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/biggan/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/cyclegan/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/imle/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/faceforensics/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/crn/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/wild/test
#
#
#
#  ------ Loading models ------
# Loading ResNet from ../KD-AIGC-Detection/checkpoints/KD/cddb_easy/gaugan_biggan_cyclegan_imle_faceforensics_crn_wild/model_best_accuracy.pth
# Loaded
# gaugan
# 100%|█████████████| 16/16 [00:04<00:00,  3.58it/s]
#
# ...

# %%
SOURCE_DATASETS = ["gaugan", "biggan", "cyclegan", "imle", "faceforensics", "crn", "wild"] 
NETWORK = "ResNet18"
CHECKPOINT_DIR_SOURCE = "../KD-AIGC-Detection/checkpoints/KD_r18/cddb_easy"
CHECKPOINT_DIR_TARGET = "../KD-AIGC-Detection/checkpoints/KD_r18/cddb_easy"
DATASET_DIR = "../KD-AIGC-Detection/datasets/custom"
COMET_NAME = "e18_cddb"


source_string = "_".join(SOURCE_DATASETS)
input_model = f"{CHECKPOINT_DIR_SOURCE}/{source_string}"

source_datasets_string = ",".join([f"{DATASET_DIR}/{ds}" for ds in SOURCE_DATASETS])

for trans in ("contrast", "brightness", "jpeg"):
    COMET_NAME2 = f"{COMET_NAME}_{trans}"
    # !python ./src/evaluate.py  --network $NETWORK \
        --input_model $input_model \
        --source_datasets $source_datasets_string \
        --use_comet \
        --val_transforms $trans \
        --comet_name $COMET_NAME2
# Out:
# COMET INFO: Experiment is live on comet.com https://www.comet.com/francescotss/paper-review/155d565332674e2fb6a967fb60242996
#
#
#
#
# ------ Creating Loaders ------
# GPU num is 0
#
# ===> Making Loader Testing
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/gaugan/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/biggan/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/cyclegan/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/imle/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/faceforensics/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/crn/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/wild/test
#
#
#
#  ------ Loading models ------
# Loading ResNet18 from ../KD-AIGC-Detection/checkpoints/KD_r18/cddb_easy/gaugan_biggan_cyclegan_imle_faceforensics_crn_wild/model_best_accuracy.pth
# Loaded
# gaugan
# 100%|█████████████| 16/16 [00:03<00:00,  4.94it/s]
#
# ...

# %%
SOURCE_DATASETS = ["gaugan", "biggan", "cyclegan", "imle", "faceforensics", "crn", "wild"] 
NETWORK = "Xception"
CHECKPOINT_DIR_SOURCE = "../KD-AIGC-Detection/checkpoints/KD_Xception/cddb_easy"
CHECKPOINT_DIR_TARGET = "../KD-AIGC-Detection/checkpoints/KD_Xception/cddb_easy"
DATASET_DIR = "../KD-AIGC-Detection/datasets/custom"
COMET_NAME = "exc_cddb"


source_string = "_".join(SOURCE_DATASETS)
input_model = f"{CHECKPOINT_DIR_SOURCE}/{source_string}"

source_datasets_string = ",".join([f"{DATASET_DIR}/{ds}" for ds in SOURCE_DATASETS])

for trans in ("contrast", "brightness", "jpeg"):
    COMET_NAME2 = f"{COMET_NAME}_{trans}"
    # !python ./src/evaluate.py  --network $NETWORK \
        --input_model $input_model \
        --source_datasets $source_datasets_string \
        --use_comet \
        --val_transforms $trans \
        --comet_name $COMET_NAME2
# Out:
# COMET INFO: Experiment is live on comet.com https://www.comet.com/francescotss/paper-review/de81860dd0f949e3ab1436ef571aae29
#
#
#
#
# ------ Creating Loaders ------
# GPU num is 0
#
# ===> Making Loader Testing
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/gaugan/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/biggan/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/cyclegan/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/imle/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/faceforensics/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/crn/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/wild/test
#
#
#
#  ------ Loading models ------
# Loading Xception from ../KD-AIGC-Detection/checkpoints/KD_Xception/cddb_easy/gaugan_biggan_cyclegan_imle_faceforensics_crn_wild/model_best_accuracy.pth
# gaugan
# 100%|█████████████| 16/16 [00:03<00:00,  4.44it/s]
#
# ...

# %%
SOURCE_DATASETS = ["gaugan", "biggan", "cyclegan", "imle", "faceforensics", "crn", "wild"] 
NETWORK = "MobileNet2"
CHECKPOINT_DIR_SOURCE = "../KD-AIGC-Detection/checkpoints/KD_mn/cddb_easy"
CHECKPOINT_DIR_TARGET = "../KD-AIGC-Detection/checkpoints/KD_mn/cddb_easy"
DATASET_DIR = "../KD-AIGC-Detection/datasets/custom"
COMET_NAME = "emn_cddb"


source_string = "_".join(SOURCE_DATASETS)
input_model = f"{CHECKPOINT_DIR_SOURCE}/{source_string}"

source_datasets_string = ",".join([f"{DATASET_DIR}/{ds}" for ds in SOURCE_DATASETS])

for trans in ("contrast", "brightness", "jpeg"):
    COMET_NAME2 = f"{COMET_NAME}_{trans}"
    # !python ./src/evaluate.py  --network $NETWORK \
        --input_model $input_model \
        --source_datasets $source_datasets_string \
        --use_comet \
        --val_transforms $trans \
        --comet_name $COMET_NAME2
# Out:
# COMET INFO: Experiment is live on comet.com https://www.comet.com/francescotss/paper-review/6dea3dfa93ea4a54ae07c7c1636aafd5
#
#
#
#
# ------ Creating Loaders ------
# GPU num is 0
#
# ===> Making Loader Testing
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/gaugan/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/biggan/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/cyclegan/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/imle/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/faceforensics/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/crn/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/wild/test
#
#
#
#  ------ Loading models ------
# Loading MobileNet2 from ../KD-AIGC-Detection/checkpoints/KD_mn/cddb_easy/gaugan_biggan_cyclegan_imle_faceforensics_crn_wild/model_best_accuracy.pth
# gaugan
# 100%|█████████████| 16/16 [00:03<00:00,  4.90it/s]
#
# ...

# %%
SOURCE_DATASETS = ["gaugan"] 
NETWORK = "ViT"
CHECKPOINT_DIR_SOURCE = "../KD-AIGC-Detection/checkpoints/KD_ViT/base"
DATASET_DIR = "../KD-AIGC-Detection/datasets/custom"
COMET_NAME = "emn_diff_elsa"


source_string = "_".join(SOURCE_DATASETS)
input_model = f"{CHECKPOINT_DIR_SOURCE}/{source_string}"

source_datasets_string = ",".join([f"{DATASET_DIR}/{ds}" for ds in SOURCE_DATASETS])

for trans in ("contrast", "brightness", "jpeg"):
    COMET_NAME2 = f"{COMET_NAME}_{trans}"
    # !python ./src/evaluate.py  --network $NETWORK \
        --input_model $input_model \
        --source_datasets $source_datasets_string \
        --use_comet \
        --val_transforms $trans \
        --comet_name $COMET_NAME2

# %% [markdown]
# # EWC

# %%
SOURCE_DATASETS = ["gaugan", "biggan", "cyclegan", "imle", "faceforensics", "crn", "wild", "diffusionshort", "elsa"] 
NETWORK = "ResNet"
CHECKPOINT_DIR_SOURCE = "../KD-AIGC-Detection/checkpoints/EWC/diff"
CHECKPOINT_DIR_TARGET = "../KD-AIGC-Detection/checkpoints/EWC/diff"
DATASET_DIR = "../KD-AIGC-Detection/datasets/custom"
COMET_NAME = "eewc50_diff_elsa"


source_string = "_".join(SOURCE_DATASETS)
input_model = f"{CHECKPOINT_DIR_SOURCE}/{source_string}"

source_datasets_string = ",".join([f"{DATASET_DIR}/{ds}" for ds in SOURCE_DATASETS])

for trans in ("contrast", "brightness", "jpeg"):
    COMET_NAME2 = f"{COMET_NAME}_{trans}"
    # !python ./src/evaluate.py  --network $NETWORK \
        --input_model $input_model \
        --source_datasets $source_datasets_string \
        --use_comet \
        --val_transforms $trans \
        --comet_name $COMET_NAME2
# Out:
# COMET INFO: Experiment is live on comet.com https://www.comet.com/francescotss/paper-review/48f9d75dce0a4acdb557ed9e71be1e13
#
#
#
#
# ------ Creating Loaders ------
# GPU num is 0
#
# ===> Making Loader Testing
# Compose(
#     RandomCrop(size=(128, 128), padding=None)
#     ColorJitter(brightness=None, contrast=(0.5, 2.0), saturation=None, hue=None)
#     ToTensor()
#     Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# )
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/gaugan/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/biggan/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/cyclegan/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/imle/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/faceforensics/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/crn/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/wild/test
# ...

# %%
SOURCE_DATASETS = ["gaugan", "biggan", "cyclegan", "imle", "faceforensics", "crn", "wild", "diffusionshort", "elsa"] 
NETWORK = "ResNet18"
CHECKPOINT_DIR_SOURCE = "../KD-AIGC-Detection/checkpoints/EWC_r18/diff"
CHECKPOINT_DIR_TARGET = "../KD-AIGC-Detection/checkpoints/EWC_r18/diff"
DATASET_DIR = "../KD-AIGC-Detection/datasets/custom"
COMET_NAME = "eewc18_diff_elsa"


source_string = "_".join(SOURCE_DATASETS)
input_model = f"{CHECKPOINT_DIR_SOURCE}/{source_string}"

source_datasets_string = ",".join([f"{DATASET_DIR}/{ds}" for ds in SOURCE_DATASETS])

for trans in ("contrast", "brightness", "jpeg"):
    COMET_NAME2 = f"{COMET_NAME}_{trans}"
    # !python ./src/evaluate.py  --network $NETWORK \
        --input_model $input_model \
        --source_datasets $source_datasets_string \
        --use_comet \
        --val_transforms $trans \
        --comet_name $COMET_NAME2
# Out:
# COMET INFO: Experiment is live on comet.com https://www.comet.com/francescotss/paper-review/623aae64840c43f68821e82936e21f2a
#
#
#
#
# ------ Creating Loaders ------
# GPU num is 0
#
# ===> Making Loader Testing
# Compose(
#     RandomCrop(size=(128, 128), padding=None)
#     ColorJitter(brightness=None, contrast=(0.5, 2.0), saturation=None, hue=None)
#     ToTensor()
#     Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# )
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/gaugan/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/biggan/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/cyclegan/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/imle/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/faceforensics/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/crn/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/wild/test
# ...

# %%
SOURCE_DATASETS = ["gaugan", "biggan", "cyclegan", "imle", "faceforensics", "crn", "wild", "diffusionshort", "elsa"] 
NETWORK = "Xception"
CHECKPOINT_DIR_SOURCE = "../KD-AIGC-Detection/checkpoints/EWC_Xception/diff"
CHECKPOINT_DIR_TARGET = "../KD-AIGC-Detection/checkpoints/EWC_Xception/diff"
DATASET_DIR = "../KD-AIGC-Detection/datasets/custom"
COMET_NAME = "eewcxc_diff"


source_string = "_".join(SOURCE_DATASETS)
input_model = f"{CHECKPOINT_DIR_SOURCE}/{source_string}"

source_datasets_string = ",".join([f"{DATASET_DIR}/{ds}" for ds in SOURCE_DATASETS])

for trans in ("contrast", "brightness", "jpeg"):
    COMET_NAME2 = f"{COMET_NAME}_{trans}"
    # !python ./src/evaluate.py  --network $NETWORK \
        --input_model $input_model \
        --source_datasets $source_datasets_string \
        --use_comet \
        --val_transforms $trans \
        --comet_name $COMET_NAME2
# Out:
# COMET INFO: Experiment is live on comet.com https://www.comet.com/francescotss/paper-review/cbffb1e4f2e645908639e871b082c36b
#
#
#
#
# ------ Creating Loaders ------
# GPU num is 0
#
# ===> Making Loader Testing
# Compose(
#     RandomCrop(size=(128, 128), padding=None)
#     ColorJitter(brightness=None, contrast=(0.5, 2.0), saturation=None, hue=None)
#     ToTensor()
#     Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# )
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/gaugan/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/biggan/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/cyclegan/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/imle/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/faceforensics/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/crn/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/wild/test
# ...

# %%
SOURCE_DATASETS = ["gaugan", "biggan", "cyclegan", "imle", "faceforensics", "crn", "wild", "diffusionshort", "elsa"] 
NETWORK = "MobileNet2"
CHECKPOINT_DIR_SOURCE = "../KD-AIGC-Detection/checkpoints/EWC_mn/diff"
CHECKPOINT_DIR_TARGET = "../KD-AIGC-Detection/checkpoints/EWC_mn/diff"
DATASET_DIR = "../KD-AIGC-Detection/datasets/custom"
COMET_NAME = "eewcmn_diff_elsa"

source_string = "_".join(SOURCE_DATASETS)
input_model = f"{CHECKPOINT_DIR_SOURCE}/{source_string}"

source_datasets_string = ",".join([f"{DATASET_DIR}/{ds}" for ds in SOURCE_DATASETS])

for trans in ("contrast", "brightness", "jpeg"):
    COMET_NAME2 = f"{COMET_NAME}_{trans}"
    # !python ./src/evaluate.py  --network $NETWORK \
        --input_model $input_model \
        --source_datasets $source_datasets_string \
        --use_comet \
        --val_transforms $trans \
        --comet_name $COMET_NAME2
# Out:
# COMET INFO: Experiment is live on comet.com https://www.comet.com/francescotss/paper-review/68be37fb092c47d780452d614c433034
#
#
#
#
# ------ Creating Loaders ------
# GPU num is 0
#
# ===> Making Loader Testing
# Compose(
#     RandomCrop(size=(128, 128), padding=None)
#     ColorJitter(brightness=None, contrast=(0.5, 2.0), saturation=None, hue=None)
#     ToTensor()
#     Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# )
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/gaugan/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/biggan/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/cyclegan/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/imle/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/faceforensics/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/crn/test
# ===> Making Loader : ../KD-AIGC-Detection/datasets/custom/wild/test
# ...
